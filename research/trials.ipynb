# %%
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x= 2, y = '2')
# Out:
# '22'

# %%
from ensure import ensure_annotations

# %%
get_product(x= 2, y = '2')

#@ensure_annotations
get_product(x= 2, y = '2')
# Out:
# '22'

# %% [markdown]
# Download dataset from googel drive

# %%
import gdown

# %%
print(gdown.__dict__)
# Out:
# {'__name__': 'gdown', '__doc__': None, '__package__': 'gdown', '__loader__': <_frozen_importlib_external.SourceFileLoader object at 0x000002B8BBA82B90>, '__spec__': ModuleSpec(name='gdown', loader=<_frozen_importlib_external.SourceFileLoader object at 0x000002B8BBA82B90>, origin='c:\\Users\\lenovo\\anaconda3\\envs\\adenocarcenoma\\lib\\site-packages\\gdown\\__init__.py', submodule_search_locations=['c:\\Users\\lenovo\\anaconda3\\envs\\adenocarcenoma\\lib\\site-packages\\gdown']), '__path__': ['c:\\Users\\lenovo\\anaconda3\\envs\\adenocarcenoma\\lib\\site-packages\\gdown'], '__file__': 'c:\\Users\\lenovo\\anaconda3\\envs\\adenocarcenoma\\lib\\site-packages\\gdown\\__init__.py', '__cached__': 'c:\\Users\\lenovo\\anaconda3\\envs\\adenocarcenoma\\lib\\site-packages\\gdown\\__pycache__\\__init__.cpython-310.pyc', '__builtins__': {'__name__': 'builtins', '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slic
# ...

# %%
url = 'https://drive.google.com/file/d/1Qqg19dtvL5YM1JcGA_Fan1T0PQuEuf7o/view?usp=drive_link'

# %%
print(type(url))
# Out:
# <class 'str'>

# %%
url.split('/')
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'file',
#  'd',
#  '1Qqg19dtvL5YM1JcGA_Fan1T0PQuEuf7o',
#  'view?usp=drive_link']

# %%
file_id = url.split('/')[-2]
file_id
# Out:
# '1Qqg19dtvL5YM1JcGA_Fan1T0PQuEuf7o'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1Qqg19dtvL5YM1JcGA_Fan1T0PQuEuf7o
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1Qqg19dtvL5YM1JcGA_Fan1T0PQuEuf7o&confirm=t&uuid=6ac004ef-2ef1-4e98-8b6a-142acaf8ebe0
# To: e:\Samay\projects\adenocarcenoma\adenocarcenoma-classificaation-end-to-end-using-mlflow-and-DVC\research\Chest-CT-Scan-data.zip
# 100%|██████████| 124M/124M [02:54<00:00, 714kB/s]
# 'Chest-CT-Scan-data.zip'

# %%
# %pwd
# Out:
# 'e:\\Samay\\projects\\adenocarcenoma\\adenocarcenoma-classificaation-end-to-end-using-mlflow-and-DVC\\research'

# %%
# To check the number of classes

import os

pat = r"E:\Samay\projects\adenocarcenoma\adenocarcenoma-classificaation-end-to-end-using-mlflow-and-DVC\artifacts\data_ingestion\Data\train"

classes = [d for d in os.listdir(pat) if os.path.isdir(os.path.join(pat, d))]
print("Classes:", classes)
print("Number of classes:", len(classes))
# Out:
# Classes: ['adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib', 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa', 'normal', 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa']
# Number of classes: 4
