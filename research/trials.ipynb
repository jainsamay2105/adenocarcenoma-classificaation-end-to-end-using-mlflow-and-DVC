# %%
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x= 2, y = '2')
# Out:
# '22'

# %%
from ensure import ensure_annotations

# %%
get_product(x= 2, y = '2')

#@ensure_annotations
get_product(x= 2, y = '2')
# Out:
# '22'
